# %% [markdown]
# EDA US Cars

# %% [markdown]
# This is a dataset of the cars for sale in the United States. From what I can see in the dataframe is the car price, type, model and general descriptors of the cars. I am going to just do some basic exploratory data analysis and clean up the data to eventually upload this to a web application for my project.

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv('C:/Users/Joe/project/drhorrible/vehicles_us.csv')
df.sample(15)
# Out:
#        price  model_year                        model  condition  cylinders  \
# 32108  19855      2018.0                 toyota camry  excellent        4.0
# 20250  18800      2011.0            cadillac escalade       good        8.0
# 26819  10500      2012.0                   gmc acadia  excellent        6.0
# 34013  10800      2015.0             chevrolet impala       good        4.0
# 18191   4250      2008.0          dodge grand caravan  excellent        6.0
# 37939  32750      2016.0                   ford f-250       good        8.0
# 22069   4900      2005.0                     ram 1500  excellent        8.0
# 11685   5500      2003.0                toyota tacoma       good        4.0
# 27419  16495      2012.0                     ram 1500  excellent        8.0
# 39531  19990         NaN                ford f-350 sd       good        8.0
# 31062   4999      2003.0              chevrolet tahoe   like new        8.0
# 12154   4995      2008.0                   gmc acadia       good        6.0
# 17976   9950      2003.0   chevrolet silverado 2500hd       good        8.0
# 20234   4999      1989.0                jeep wrangler       good        NaN
# 5956   27000         NaN  ford f150 supercrew cab xlt       good        6.0
#
#          fuel  odometer transmission      type paint_color  is_4wd  \
# 32108     gas   25077.0    automatic     sedan        grey     NaN
# 20250     gas  102255.0    automatic       SUV       black     NaN
# 26819     gas  118000.0    automatic       SUV       white     1.0
# 34013     gas       NaN    automatic     sedan         NaN     NaN
# 18191     gas  150000.0    automatic  mini-van        blue     NaN
# 37939  diesel   98500.0    automatic     truck         NaN     1.0
# 22069     gas       NaN    automatic     truck      silver     1.0
# 11685     gas  298698.0    automatic    pickup       black     NaN
# 27419     gas  140500.0    automatic    pickup        blue     1.0
# 39531     gas   54561.0    automatic     truck         NaN     NaN
# 31062     gas  140000.0    automatic       SUV         NaN     NaN
# 12154     gas  191232.0    automatic       SUV      purple     NaN
# 17976     gas  110000.0    automatic    pickup      silver     1.0
# 20234     gas  138000.0       manual       SUV         NaN     1.0
# 5956      gas   36300.0        other    pickup         NaN     1.0
#
#       date_posted  days_listed
# 32108  2019-01-22           11
# 20250  2018-12-27            2
# 26819  2018-06-19           87
# 34013  2019-02-26           20
# 18191  2018-09-11           24
# 37939  2019-03-09           52
# 22069  2018-06-03           22
# 11685  2018-12-29           16
# 27419  2018-12-26           24
# 39531  2019-03-12          101
# 31062  2019-02-05           42
# 12154  2018-06-01            4
# 17976  2019-03-18           15
# 20234  2018-12-13           60
# 5956   2018-08-10           53

# %% [markdown]
# Ok so first off, there's a lot going on. The model year is a float value, the type of the cars aren't all lowercase, is_4wd looks like it runs off a yes/no system but fills the value with 1 if it fulfills that criteria, and date_posted is not in datetime. All of these are simple fixes that are also verified below by getting the info of the dataframe. Also there's something going on where the price is listed as 1 for some cars, that will be explored further at a later time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  47906.000000  46265.000000   43633.000000  25572.0
# mean    12132.464920   2009.750470      6.125235  115553.461738      1.0
# std     10040.803015      6.282065      1.660360   65094.611341      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2006.000000      4.000000   70000.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  113000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  155000.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %% [markdown]
# So this gives me a lot of information about the numerical aspects of the data such as the price and odometer. For example something weird is that some of the prices are labeled as 1. This is strange because this could either be an error or maybe it's meant for you to contact the owner for pricing. Odometer also has a weird max value of almost 1 million miles, for now I will filter out the cars priced at 1 as it could clutter and mess with our data.

# %%
df = df[df['price'] != 1]

# %%
# changing the date_posted to datetime in case of any date related data analysis later
df['date_posted'] = pd.to_datetime(df['date_posted'])

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# price               0
# model_year       3567
# model               0
# condition           0
# cylinders        5189
# fuel                0
# odometer         7769
# transmission        0
# type                0
# paint_color      9116
# is_4wd          25821
# date_posted         0
# days_listed         0
# dtype: int64

# %%
duplicate_vaules = df.duplicated().sum()
duplicate_vaules
# Out:
# np.int64(0)

# %% [markdown]
# Great, we know where the missing values are and we do not have to worry about duplicate values, we will go down the list addressing the missing values in each column.

# %%
# convert model_year to numeric since car manufacturers don't use have years and dropped missing values from the model year. This should be ok as long as the model_year isn't too crucial to the data in my opinion
df['model_year'] = pd.to_numeric(df['model_year'])
df.dropna(subset=['model_year'], inplace=True)
df['model_year'].isna().sum()
# Out:
# np.int64(0)

# %%
df['cylinders'] = pd.to_numeric(df['cylinders'])
df.dropna(subset=['cylinders'], inplace=True)
df['cylinders'].isna().sum()
# Out:
# np.int64(0)

# %%
# I have a bit of a dilemma concerning the odometer. I don't want to just eliminate NaN values but I would not know a safe replacement. Two options I'm thinking of are dropna() or just fillna() with "Unknown"
df.dropna(subset=['odometer'], inplace=True)
df['odometer'].isna().sum()
# Out:
# np.int64(0)

# %%
df['paint_color'] = df['paint_color'].fillna('not_listed')
df['paint_color'].isna().sum()
# Out:
# np.int64(0)

# %%
df['is_4wd'] = df['is_4wd'].replace(1, "yes",).fillna('no')
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
#
#   transmission   type paint_color is_4wd date_posted  days_listed
# 0    automatic    SUV  not_listed    yes  2018-06-23           19
# 2    automatic  sedan         red     no  2019-02-07           79
# 4    automatic  sedan       black     no  2019-04-02           28
# 5    automatic  sedan       black    yes  2018-06-20           15
# 6    automatic  sedan       white     no  2018-12-27           73

# %%
df.isna().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %% [markdown]
# Ok we have handled all the missing values. Now it's time to do a bit more cleaning like making the type of car all lowercase and then make some graphs and histograms

# %%
df['type'] = df['type'].str.lower()
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990      2014.0    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990      2015.0    toyota camry  excellent        4.0  gas   79212.0
#
#   transmission   type paint_color is_4wd date_posted  days_listed
# 0    automatic    suv  not_listed    yes  2018-06-23           19
# 2    automatic  sedan         red     no  2019-02-07           79
# 4    automatic  sedan       black     no  2019-04-02           28
# 5    automatic  sedan       black    yes  2018-06-20           15
# 6    automatic  sedan       white     no  2018-12-27           73

# %%
# spaces need to have underscores
df['model'] = df['model'].str.replace(' ', '_')
df.head(20)
# Out:
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw_x5       good        6.0  gas
# 2    5500      2013.0            hyundai_sonata   like new        4.0  gas
# 4   14900      2017.0              chrysler_200  excellent        4.0  gas
# 5   14990      2014.0              chrysler_300  excellent        6.0  gas
# 6   12990      2015.0              toyota_camry  excellent        4.0  gas
# 7   15990      2013.0               honda_pilot  excellent        6.0  gas
# 8   11500      2012.0               kia_sorento  excellent        4.0  gas
# 10  19500      2011.0  chevrolet_silverado_1500  excellent        8.0  gas
# 11   8990      2012.0              honda_accord  excellent        4.0  gas
# 12  18990      2012.0                  ram_1500  excellent        8.0  gas
# 13  16500      2018.0            hyundai_sonata  excellent        4.0  gas
# 14  12990      2009.0                 gmc_yukon  excellent        8.0  gas
# 16  14990      2010.0                  ram_1500  excellent        8.0  gas
# 17  13990      2014.0             jeep_cherokee  excellent        6.0  gas
# 18  12500      2013.0        chevrolet_traverse  excellent        6.0  gas
# 19  13990      2018.0           hyundai_elantra  excellent        4.0  gas
# 21   5250      2007.0               toyota_rav4       good        6.0  gas
# 22   7500      2004.0       chevrolet_silverado   like new        8.0  gas
# 26   8499      2014.0            ford_fusion_se   like new        4.0  gas
# 27  12999      2015.0          chevrolet_impala   like new        6.0  gas
#
#     odometer transmission    type paint_color is_4wd date_posted  days_listed
# 0   145000.0    automatic     suv  not_listed    yes  2018-06-23           19
# 2   110000.0    automatic   sedan         red     no  2019-02-07           79
# 4    80903.0    automatic   sedan       black     no  2019-04-02           28
# 5    57954.0    automatic   sedan       black    yes  2018-06-20           15
# 6    79212.0    automatic   sedan       white     no  2018-12-27           73
# 7   109473.0    automatic     suv       black    yes  2019-01-07           68
# 8   104174.0    automatic     suv  not_listed    yes  2018-07-16           19
# 10  128413.0    automatic  pickup       black    yes  2018-09-17           38
# 11  111142.0    automatic   sedan        grey     no  2019-03-28           29
# 12  140742.0    automatic  pickup  not_listed    yes  2019-04-02           37
# 13   22104.0    automatic   sedan      silver     no  2019-01-14           29
# 14  132285.0    automatic     suv       black    yes  2019-01-31           24
# 16  130725.0    automatic  pickup         red    yes  2018-12-30           13
# 17  100669.0    automatic     suv         red    yes  2018-08-16           25
# 18  128325.0    automatic     suv       white    yes  2019-04-09           13
# 19   31932.0    automatic   sedan         red     no  2018-08-25           27
# 21  154000.0    automatic     suv  not_listed     no  2018-08-22            8
# 22  180000.0    automatic   truck         red    yes  2019-01-05           64
# 26   79523.0    automatic   sedan         red     no  2018-10-25           23
# 27   39368.0    automatic   sedan      custom     no  2018-05-19           42

# %%
# Histogram for Car price per car type
fig = px.histogram(df, x='price', color='type', nbins=50, title='Price Distribution by Car Type', opacity=0.7, barmode='overlay')
fig.show()

# Histogram of Price by car's condition
fig= px.histogram(df, x='price', color='condition', nbins=50, title='Price Distribution by Car Condition', opacity=0.7, barmode='overlay')
fig.show()

# %%
# Scatter Plot for Price vs Odometer
fig = px.scatter(df, x='odometer', y='price', color='type', title='Price vs. Odometer of Car Type')
fig.show()

# Scatter Plot for Price vs Model Year
fig = px.scatter(df, x='model_year', y='price', color='model', title='Price vs. Model Year')
fig.show()
